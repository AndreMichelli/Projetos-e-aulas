# %% [markdown]
# # AULA - 18 - EXERCÍCIOS - MATPLOTLIB - SOLUÇÃO

# %% [markdown]
# ## Neste notebook, vamos desempenhar alguns exercícios para o treinamento da biblioteca do Matplotlib

# %% [markdown]
# ### Siga as instruções para recriar gráficos utilizando os dados abaixo:

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### 1 - Importe o Matplotlib como plt.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2 - Como fazemos para que, após rodar a linha, o gráfico seja mostrado? Além disso, para quem não usa o jupyter notebook, é necessário um comando especifico para demostrar o gráfico criado, qual é?

# %%
# %matplotlib inline
# plt.show() para não usuários do Notebook

# %% [markdown]
# #### 3 - Acompanhe estes passos:
# *  Crie um objeto de figura chamado fig usando plt.figure ()
# *  Use add_axes para adicionar um eixo à tela de figura em [0,0,1,1]. Chame esse novo eixo de "ax".
# * Plote (x, y) nesses eixos e defina os rótulos e títulos para corresponder ao gráfico abaixo:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# #### 4 - Crie um objeto de figura e coloque dois eixos sobre ele, ax1 e ax2. Localizado em [0,0,1,1] e [0,2,0,5, .2, .2], respectivamente.

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# #### 5 - Agora plote (x, y) em ambos os eixos. E chame seu objeto de figura para mostrá-lo.

# %%
ax1.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')


ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')

fig

# %% [markdown]
# #### 6 - Crie o gráfico abaixo, adicionando dois eixos a um objeto de figura em [0,0,1,1] e [0,2,0,5, .4, .4]

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# #### 7 - Agora use x, y e z arrays para recriar o gráfico abaixo.

# %%
ax.plot(x,z)
ax.set_xlabel('X')
ax.set_ylabel('Z')
ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
fig

# %% [markdown]
# #### 8 - Use plt.subplots (nrows = 1, ncols = 2) para criar o gráfico abaixo.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# #### 9 - Agora trace (x, y) e (x, z) nos eixos. Note a largura de linha e o estilo objetivos.

# %%
axes[0].plot(x,y,color="blue", lw=3, ls='--')
axes[1].plot(x,z,color="red", lw=3, ls='-')
fig

# %% [markdown]
# #### 10 - Veja se você pode redimensionar o gráfico adicionando o argumento figsize () em plt.subplots () apenas copiando e colando seu código anterior.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

axes[0].plot(x,y,color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')
