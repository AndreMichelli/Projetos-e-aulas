# %% [markdown]
# # AULA 24 - EXERCÍCIOS - SEABORN - SOLUÇÃO

# %% [markdown]
# ## Neste notebook, vamos desempenhar alguns exercícios para treinamento do que foi visto no módulo

# %% [markdown]
# * ##### Há uma linha livre após a representação do gráfico para que você possa dispor sua resposta sem que apague o que foi pedido.

# %% [markdown]
# ### Siga as instruções para recriar a saida dada a seguir.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### 1 - Recrie os gráficos abaixo utilizando os devidos métodos da biblioteca, utilizando as informações acima.

# %% [markdown]
# * #### A -

# %%
sns.jointplot(x='fare', y='age', data=titanic)

# %% [markdown]
# * #### B -

# %%
sns.distplot(titanic['fare'])

# %% [markdown]
# * #### C -

# %%
sns.boxplot(x='class',y='age',data=titanic)

# %% [markdown]
# * #### D -

# %%
sns.swarmplot(x='class',y='age',data=titanic)
# Out:
# C:\Users\andre\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\andre\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# * #### E -

# %%
sns.countplot(x='sex',data=titanic)

# %% [markdown]
# * #### F -

# %%
corr = titanic.corr()
sns.heatmap(corr)

# %% [markdown]
# * #### G -

# %%
g=sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist, 'age')
